# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
data = pd.read_csv(r'C:\Users\45471\OneDrive\Desktop\deepsolar_tract.csv', encoding = 'latin1')
print("The dataset has " + str(data.shape[0]) + " rows and " + str(data.shape[1]) + " columns.")
data.head()
# Out:
# The dataset has 72537 rows and 169 columns.
#    Unnamed: 0  tile_count  solar_system_count  total_panel_area         fips  \
# 0           0         0.0                 0.0          0.000000  27145011200
# 1           1        25.0                21.0       1133.436461  27145011301
# 2           2         3.0                 3.0         64.505776  27145011302
# 3           3         0.0                 0.0          0.000000  27145011304
# 4           4         5.0                 5.0        164.583303  27145011400
#
#    average_household_income          county  education_bachelor  \
# 0              70352.789869  Stearns County                 569
# 1              61727.085202  Stearns County                 674
# 2              71496.886583  Stearns County                 854
# 3              86840.152755  Stearns County                 640
# 4              89135.315597  Stearns County                 654
#
#    education_college  education_doctoral  education_high_school_graduate  \
# 0               1690                  13                            1757
# 1               1434                 108                             767
# 2               1459                  31                            1541
# 3               1116                  68                            1095
# 4               1314                  15                             982
#
#    education_less_than_high_school  education_master  education_population  \
# 0                              336               157                  4548
# 1                              222               285                  3533
# 2                              289               276                  4480
# 3                              231               270                  3456
# 4                              163               170                  3348
#
#    education_professional_school  employed  gini_index  \
# 0                             26      3569      0.3490
# 1                             43      4795      0.4074
# 2                             30      3550      0.3926
# 3                             36      3483      0.3949
# 4                             50      2887      0.4463
#
#    heating_fuel_coal_coke  heating_fuel_electricity  \
# 0                     200                       448
# 1                      20                       379
# 2                      69                       440
# 3                     188                       442
# 4                      96                       497
#
#    heating_fuel_fuel_oil_kerosene  heating_fuel_gas  \
# 0                              98              1720
# 1                              17              1799
# 2                              45              2098
# 3                              61              1113
# 4                              47              1202
#
#    heating_fuel_housing_unit_count  heating_fuel_none  heating_fuel_other  \
# 0                             2527                 10                  51
# 1                             2230                  0                  15
# 2                             2698                 29                  17
# 3                             1833                 13                  16
# 4                             1917                 31                  44
#
#    heating_fuel_solar  land_area  per_capita_income  population  \
# 0                   0  147.73120            26999.0        6577
# 1                   0   16.61679            20951.0        8020
# 2                   0   37.44482            28021.0        6971
# 3                   0   75.21147            29275.0        6328
# 4                   0   44.00151            32770.0        5264
#
#    population_density  poverty_family_below_poverty_level  \
# 0            44.52005                                  85
# 1           482.64430                                 189
# 2           186.16730                                 134
# 3            84.13610                                  87
# 4           119.63230                                  73
#
#    poverty_family_count  race_asian  race_black_africa  race_indian_alaska  \
# 0                  1911          28                 19                  16
# 1                  1359         188                205                  23
# 2                  1961           0                  0                   2
# 3                  1499         171                 69                  26
# 4                  1473          34                 91                   0
#
#    race_islander  race_other  race_two_more  race_white state  total_area  \
# 0              0           6             88        6420    mn   154.37190
# 1              0          67            132        7405    mn    16.69968
# 2              0          18             12        6939    mn    39.33050
# 3              0         305             64        5693    mn    81.04071
# 4              0           0            122        5017    mn    44.60017
#
#    unemployed  water_area  education_less_than_high_school_rate  \
# 0         136    6.640769                              0.073879
# 1         233    0.082887                              0.062836
# 2         151    1.885683                              0.064509
# 3         186    5.829235                              0.066840
# 4         154    0.598656                              0.048686
#
#    education_high_school_graduate_rate  education_college_rate  \
# 0                             0.386324                0.371592
# 1                             0.217096                0.405887
# 2                             0.343973                0.325670
# 3                             0.316840                0.322917
# 4                             0.293309                0.392473
#
#    education_bachelor_rate  education_master_rate  \
# 0                 0.125110               0.034521
# 1                 0.190773               0.080668
# 2                 0.190625               0.061607
# 3                 0.185185               0.078125
# 4                 0.195341               0.050777
#
#    education_professional_school_rate  education_doctoral_rate  \
# 0                            0.005717                 0.002858
# 1                            0.012171                 0.030569
# 2                            0.006696                 0.006920
# 3                            0.010417                 0.019676
# 4                            0.014934                 0.004480
#
#    race_white_rate  race_black_africa_rate  race_indian_alaska_rate  \
# 0         0.976129                0.002889                 0.002433
# 1         0.923317                0.025561                 0.002868
# 2         0.995410                0.000000                 0.000287
# 3         0.899652                0.010904                 0.004109
# 4         0.953078                0.017287                 0.000000
#
#    race_asian_rate  race_islander_rate  race_other_rate  race_two_more_rate  \
# 0         0.004257                 0.0         0.000912            0.013380
# 1         0.023441                 0.0         0.008354            0.016459
# 2         0.000000                 0.0         0.002582            0.001721
# 3         0.027023                 0.0         0.048198            0.010114
# 4         0.006459                 0.0         0.000000            0.023176
#
#    employ_rate  poverty_family_below_poverty_level_rate  \
# 0     0.963293                                 0.044479
# 1     0.953660                                 0.139073
# 2     0.959200                                 0.068332
# 3     0.949305                                 0.058039
# 4     0.949359                                 0.049559
#
#    heating_fuel_gas_rate  heating_fuel_electricity_rate  \
# 0               0.680649                       0.177285
# 1               0.806726                       0.169955
# 2               0.777613                       0.163084
# 3               0.607201                       0.241135
# 4               0.627021                       0.259259
#
#    heating_fuel_fuel_oil_kerosene_rate  heating_fuel_coal_coke_rate  \
# 0                             0.038781                     0.079145
# 1                             0.007623                     0.008969
# 2                             0.016679                     0.025574
# 3                             0.033279                     0.102564
# 4                             0.024517                     0.050078
#
#    heating_fuel_solar_rate  heating_fuel_other_rate  heating_fuel_none_rate  \
# 0                      0.0                 0.020182                0.003957
# 1                      0.0                 0.006726                0.000000
# 2                      0.0                 0.006301                0.010749
# 3                      0.0                 0.008729                0.007092
# 4                      0.0                 0.022953                0.016171
#
#    solar_panel_area_divided_by_area  solar_panel_area_per_capita  \
# 0                          0.000000                     0.000000
# 1                         17.801218                     0.037067
# 2                          1.640095                     0.009253
# 3                          0.000000                     0.000000
# 4                          1.368842                     0.011598
#
#    tile_count_residential  tile_count_nonresidential  \
# 0                     0.0                        0.0
# 1                    17.0                        8.0
# 2                     3.0                        0.0
# 3                     0.0                        0.0
# 4                     4.0                        1.0
#
#    solar_system_count_residential  solar_system_count_nonresidential  \
# 0                             0.0                                0.0
# 1                            15.0                                6.0
# 2                             3.0                                0.0
# 3                             0.0                                0.0
# 4                             4.0                                1.0
#
#    total_panel_area_residential  total_panel_area_nonresidential  \
# 0                      0.000000                         0.000000
# 1                    297.274652                       836.161809
# 2                     64.505776                         0.000000
# 3                      0.000000                         0.000000
# 4                     61.050581                       103.532723
#
#    median_household_income  electricity_price_residential  \
# 0                  64232.0                          12.12
# 1                  49778.0                          12.12
# 2                  63355.0                          12.12
# 3                  71599.0                          12.12
# 4                  68401.0                          12.12
#
#    electricity_price_commercial  electricity_price_industrial  \
# 0                          9.44                          7.02
# 1                          9.44                          7.02
# 2                          9.44                          7.02
# 3                          9.44                          7.02
# 4                          9.44                          7.02
#
#   electricity_price_transportation  electricity_price_overall  \
# 0                              9.5                       9.53
# 1                              9.5                       9.53
# 2                              9.5                       9.53
# 3                              9.5                       9.53
# 4                              9.5                       9.53
#
#    electricity_consume_residential  electricity_consume_commercial  \
# 0                              762                            6743
# 1                              762                            6743
# 2                              762                            6743
# 3                              762                            6743
# 4                              762                            6743
#
#    electricity_consume_industrial  electricity_consume_total  household_count  \
# 0                          182201                     189706             2527
# 1                          182201                     189706             2230
# 2                          182201                     189706             2698
# 3                          182201                     189706             1833
# 4                          182201                     189706             1917
#
#    average_household_size  housing_unit_count  housing_unit_occupied_count  \
# 0                    2.58                2931                         2527
# 1                    2.75                2356                         2230
# 2                    2.55                2909                         2698
# 3                    2.57                2226                         1833
# 4                    2.74                2004                         1917
#
#    housing_unit_median_value  housing_unit_median_gross_rent     lat     lon  \
# 0                   192500.0                           814.0  45.369 -94.282
# 1                   157000.0                           733.0     NaN     NaN
# 2                   182400.0                           692.0  45.460 -94.425
# 3                   251400.0                           681.0  45.507 -94.388
# 4                   208600.0                           882.0  45.457 -94.182
#
#    elevation  heating_design_temperature  cooling_design_temperature  \
# 0      358.0                       -16.7                       25.78
# 1        NaN                         NaN                         NaN
# 2      358.0                       -16.7                       25.78
# 3      358.0                       -16.7                       25.78
# 4      358.0                       -16.7                       25.78
#
#    earth_temperature_amplitude  frost_days  air_temperature  \
# 0                        24.07       154.0              5.4
# 1                          NaN         NaN              NaN
# 2                        24.07       154.0              5.4
# 3                        24.07       154.0              5.4
# 4                        24.07       154.0              5.4
#
#    relative_humidity  daily_solar_radiation  atmospheric_pressure  wind_speed  \
# 0              0.695                   3.76                  97.4         4.4
# 1                NaN                    NaN                   NaN         NaN
# 2              0.695                   3.76                  97.4         4.4
# 3              0.695                   3.76                  97.4         4.4
# 4              0.695                   3.76                  97.4         4.4
#
#    earth_temperature  heating_degree_days  cooling_degree_days  \
# 0                5.7               4810.0               1278.0
# 1                NaN                  NaN                  NaN
# 2                5.7               4810.0               1278.0
# 3                5.7               4810.0               1278.0
# 4                5.7               4810.0               1278.0
#
#    age_18_24_rate  age_25_34_rate  age_more_than_85_rate  age_75_84_rate  \
# 0        0.078759        0.095028               0.008058        0.046374
# 1        0.377182        0.108603               0.009975        0.039526
# 2        0.079902        0.093817               0.032277        0.050782
# 3        0.283660        0.075221               0.005689        0.041245
# 4        0.090616        0.142477               0.005509        0.028875
#
#    age_35_44_rate  age_45_54_rate  age_65_74_rate  age_55_64_rate  \
# 0        0.109624        0.189600        0.085145        0.157671
# 1        0.095885        0.091521        0.034040        0.060973
# 2        0.120069        0.151485        0.079759        0.114474
# 3        0.075695        0.133534        0.076327        0.138432
# 4        0.120631        0.149506        0.060410        0.128609
#
#    age_10_14_rate  age_15_17_rate  age_5_9_rate  household_type_family_rate  \
# 0        0.075262        0.045157      0.064771                    0.756233
# 1        0.036284        0.024314      0.061721                    0.609417
# 2        0.100273        0.057381      0.065701                    0.726835
# 3        0.041403        0.035556      0.048357                    0.817785
# 4        0.049962        0.039704      0.103723                    0.768388
#
#    dropout_16_19_inschool_rate  occupation_construction_rate  \
# 0                     1.000000                      0.113757
# 1                     0.966867                      0.066945
# 2                     0.989605                      0.050986
# 3                     0.988485                      0.095607
# 4                     0.946565                      0.068237
#
#    occupation_public_rate  occupation_information_rate  \
# 0                0.024096                     0.012609
# 1                0.018561                     0.011053
# 2                0.024789                     0.004789
# 3                0.022394                     0.014355
# 4                0.014548                     0.011084
#
#    occupation_finance_rate  occupation_education_rate  \
# 0                 0.044830                   0.203699
# 1                 0.046507                   0.410636
# 2                 0.081972                   0.256338
# 3                 0.029859                   0.300316
# 4                 0.056460                   0.240734
#
#    occupation_administrative_rate  occupation_manufacturing_rate  \
# 0                        0.053797                       0.177080
# 1                        0.034619                       0.103024
# 2                        0.085352                       0.197183
# 3                        0.063164                       0.144416
# 4                        0.125390                       0.158989
#
#    occupation_wholesale_rate  occupation_retail_rate  \
# 0                   0.021855                0.117960
# 1                   0.010636                0.103233
# 2                   0.020845                0.100845
# 3                   0.035889                0.085558
# 4                   0.027710                0.123311
#
#    occupation_transportation_rate  occupation_arts_rate  \
# 0                        0.063603              0.063323
# 1                        0.032534              0.068613
# 2                        0.046197              0.048169
# 3                        0.039334              0.095607
# 4                        0.058538              0.041912
#
#    occupation_agriculture_rate  occupancy_vacant_rate  occupancy_owner_rate  \
# 0                     0.059681               0.137837              0.776868
# 1                     0.004797               0.053480              0.683786
# 2                     0.030704               0.072534              0.776212
# 3                     0.035889               0.176550              0.745283
# 4                     0.029789               0.043413              0.678643
#
#    mortgage_with_rate  transportation_home_rate  \
# 0            0.627580                  0.088343
# 1            0.644320                  0.135403
# 2            0.640390                  0.033475
# 3            0.637734                  0.135988
# 4            0.601471                  0.042524
#
#    transportation_car_alone_rate  transportation_walk_rate  \
# 0                       0.795371                  0.019193
# 1                       0.596433                  0.091590
# 2                       0.841986                  0.034894
# 3                       0.677795                  0.079020
# 4                       0.843848                  0.016731
#
#    transportation_carpool_rate  transportation_motorcycle_rate  \
# 0                     0.086367                        0.003387
# 1                     0.095332                        0.000000
# 2                     0.076879                        0.008794
# 3                     0.086677                        0.001225
# 4                     0.088184                        0.000000
#
#    transportation_bicycle_rate  transportation_public_rate  \
# 0                     0.002258                    0.003669
# 1                     0.000000                    0.064509
# 2                     0.000000                    0.000000
# 3                     0.001838                    0.014395
# 4                     0.000000                    0.002440
#
#    travel_time_less_than_10_rate  travel_time_10_19_rate  \
# 0                       0.130341                0.212693
# 1                       0.239878                0.431373
# 2                       0.236865                0.206927
# 3                       0.190358                0.344913
# 4                       0.119767                0.344376
#
#    travel_time_20_29_rate  travel_time_30_39_rate  travel_time_40_59_rate  \
# 0                0.213932                0.241176                0.088854
# 1                0.175452                0.050166                0.028520
# 2                0.262107                0.199296                0.042559
# 3                0.251684                0.114498                0.060262
# 4                0.294503                0.098289                0.046960
#
#    travel_time_60_89_rate  health_insurance_public_rate  \
# 0                0.067802                      0.249962
# 1                0.008403                      0.245761
# 2                0.041385                      0.255264
# 3                0.021624                      0.185051
# 4                0.065890                      0.272710
#
#    health_insurance_none_rate  age_median  travel_time_average  \
# 0                    0.070330        43.9                 29.0
# 1                    0.043890        21.9                 22.0
# 2                    0.037171        39.6                 21.0
# 3                    0.050727        30.9                 21.0
# 4                    0.023424        34.5                 25.0
#
#    voting_2016_dem_percentage  voting_2016_gop_percentage  \
# 0                    0.323796                    0.602874
# 1                    0.323796                    0.602874
# 2                    0.323796                    0.602874
# 3                    0.323796                    0.602874
# 4                    0.323796                    0.602874
#
#    voting_2016_dem_win  voting_2012_dem_percentage  \
# 0                False                       0.429
# 1                False                       0.429
# 2                False                       0.429
# 3                False                       0.429
# 4                False                       0.429
#
#    voting_2012_gop_percentage  voting_2012_dem_win  \
# 0                        0.55                False
# 1                        0.55                False
# 2                        0.55                False
# 3                        0.55                False
# 4                        0.55                False
#
#    number_of_years_of_education  diversity  \
# 0                     13.232410   0.046960
# 1                     14.192188   0.145934
# 2                     13.647991   0.009150
# 3                     13.858796   0.187334
# 4                     13.850956   0.090766
#
#    number_of_solar_system_per_household  incentive_count_residential  \
# 0                              0.000000                           34
# 1                              0.006726                           34
# 2                              0.001112                           34
# 3                              0.000000                           34
# 4                              0.002087                           34
#
#    incentive_count_nonresidential  incentive_residential_state_level  \
# 0                              39                                 11
# 1                              39                                 11
# 2                              39                                 11
# 3                              39                                 11
# 4                              39                                 11
#
#    incentive_nonresidential_state_level  net_metering  feedin_tariff  \
# 0                                    13            34              0
# 1                                    13            34              0
# 2                                    13            34              0
# 3                                    13            34              0
# 4                                    13            34              0
#
#    cooperate_tax  property_tax  sales_tax  rebate  avg_electricity_retail_rate
# 0              0            25         12       0                         9.46
# 1              0            25         12       0                         9.46
# 2              0            25         12       0                         9.46
# 3              0            25         12       0                         9.46
# 4              0            25         12       0                         9.46

# %%
# select features
selected_features = ['tile_count', 
                   'tile_count_residential', 
                   'total_panel_area_residential',
                   'solar_panel_area_divided_by_area', 
                   'solar_panel_area_per_capita',
                   'solar_system_count_residential', 
                   'solar_system_count_nonresidential',
                   'number_of_solar_system_per_household', 
                   'number_of_years_of_education',
                   'diversity', 
                   'average_household_income', 
                   'county', 
                   'employed', 
                   'gini_index',
                   'land_area', 
                   'per_capita_income', 
                   'population', 
                   'population_density',
                   'state', 
                   'total_area', 
                   'water_area', 
                   'employ_rate', 
                   'poverty_family_below_poverty_level_rate',
                   'heating_fuel_solar_rate', 
                   'median_household_income', 
                   'household_count',
                   'average_household_size', 
                   'housing_unit_count', 
                   'housing_unit_occupied_count',
                   'housing_unit_median_value', 
                   'housing_unit_median_gross_rent', 
                   'age_18_24_rate',
                   'age_25_34_rate',
                   'age_more_than_85_rate', 
                   'age_75_84_rate', 
                   'age_35_44_rate',
                   'age_45_54_rate',
                   'age_65_74_rate', 
                   'age_55_64_rate', 
                   'age_10_14_rate', 
                   'age_15_17_rate', 
                   'age_5_9_rate',
                   'household_type_family_rate', 
                   'dropout_16_19_inschool_rate', 
                   'mortgage_with_rate',
                   'occupancy_vacant_rate', 
                   'occupancy_owner_rate', 
                   'age_median', 
                   'travel_time_average',
                   'health_insurance_public_rate', 
                   'health_insurance_none_rate', 
                   'daily_solar_radiation',
                   'net_metering',
                   'feedin_tariff',
                   'cooperate_tax', 
                   'property_tax', 
                   'sales_tax',
                   'rebate',
                   'avg_electricity_retail_rate']

# %%
# Size of data
data = data[selected_features]
print('Selected data has %d rows and %d columns' % (data.shape[0], data.shape[1]))
# Out:
# Selected data has 72537 rows and 59 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72537 entries, 0 to 72536
# Data columns (total 59 columns):
# tile_count                                 72537 non-null float64
# tile_count_residential                     72537 non-null float64
# total_panel_area_residential               72537 non-null float64
# solar_panel_area_divided_by_area           72513 non-null float64
# solar_panel_area_per_capita                72074 non-null float64
# solar_system_count_residential             72537 non-null float64
# solar_system_count_nonresidential          72537 non-null float64
# number_of_solar_system_per_household       71991 non-null float64
# number_of_years_of_education               71930 non-null float64
# diversity                                  71940 non-null float64
# average_household_income                   71651 non-null float64
# county                                     72537 non-null object
# employed                                   72537 non-null int64
# gini_index                                 71690 non-null float64
# land_area                                  72513 non-null float64
# per_capita_income                          71894 non-null float64
# population                                 72537 non-null int64
# population_density                         72221 non-null float64
# state                                      72537 non-null object
# total_area                                 72513 non-null float64
# water_area                                 72513 non-null float64
# employ_rate                                71831 non-null float64
# poverty_family_below_poverty_level_rate    71714 non-null float64
# heating_fuel_solar_rate                    71766 non-null float64
# median_household_income                    71580 non-null float64
# household_count                            72537 non-null int64
# average_household_size                     71729 non-null float64
# housing_unit_count                         72537 non-null int64
# housing_unit_occupied_count                72537 non-null int64
# housing_unit_median_value                  70643 non-null float64
# housing_unit_median_gross_rent             70561 non-null float64
# age_18_24_rate                             71940 non-null float64
# age_25_34_rate                             71940 non-null float64
# age_more_than_85_rate                      71940 non-null float64
# age_75_84_rate                             71940 non-null float64
# age_35_44_rate                             71940 non-null float64
# age_45_54_rate                             71940 non-null float64
# age_65_74_rate                             71940 non-null float64
# age_55_64_rate                             71940 non-null float64
# age_10_14_rate                             71940 non-null float64
# age_15_17_rate                             71940 non-null float64
# age_5_9_rate                               71940 non-null float64
# household_type_family_rate                 71766 non-null float64
# dropout_16_19_inschool_rate                71476 non-null float64
# mortgage_with_rate                         71401 non-null float64
# occupancy_vacant_rate                      71791 non-null float64
# occupancy_owner_rate                       71791 non-null float64
# age_median                                 71907 non-null float64
# travel_time_average                        71690 non-null float64
# health_insurance_public_rate               71836 non-null float64
# health_insurance_none_rate                 71836 non-null float64
# daily_solar_radiation                      66735 non-null float64
# net_metering                               72537 non-null int64
# feedin_tariff                              72537 non-null int64
# cooperate_tax                              72537 non-null int64
# property_tax                               72537 non-null int64
# sales_tax                                  72537 non-null int64
# rebate                                     72537 non-null int64
# avg_electricity_retail_rate                72537 non-null float64
# dtypes: float64(46), int64(11), object(2)
# memory usage: 32.7+ MB

# %%
# residential area that deployed solar system
data = data.loc[data['tile_count_residential'] > 0]
print('the shape of data table of residents with solar panels installed is %d rows and %d columns' % (data.shape[0], data.shape[1]))
# Out:
# the shape of data table of residents with solar panels installed is 53529 rows and 59 columns

# %%
data.head()
# Out:
#    tile_count  tile_count_residential  total_panel_area_residential  \
# 1        25.0                    17.0                    297.274652
# 2         3.0                     3.0                     64.505776
# 4         5.0                     4.0                     61.050581
# 6         2.0                     2.0                     25.299013
# 9        11.0                     9.0                    283.951203
#
#    solar_panel_area_divided_by_area  solar_panel_area_per_capita  \
# 1                         17.801218                     0.037067
# 2                          1.640095                     0.009253
# 4                          1.368842                     0.011598
# 6                         49.002875                     0.007220
# 9                         35.169588                     0.033390
#
#    solar_system_count_residential  solar_system_count_nonresidential  \
# 1                            15.0                                6.0
# 2                             3.0                                0.0
# 4                             4.0                                1.0
# 6                             2.0                                0.0
# 9                             9.0                                1.0
#
#    number_of_solar_system_per_household  number_of_years_of_education  \
# 1                              0.006726                     14.192188
# 2                              0.001112                     13.647991
# 4                              0.002087                     13.850956
# 6                              0.004255                     14.404110
# 9                              0.002742                     14.254816
#
#    diversity  average_household_income          county  employed  gini_index  \
# 1   0.145934              61727.085202  Stearns County      4795      0.4074
# 2   0.009150              71496.886583  Stearns County      3550      0.3926
# 4   0.090766              89135.315597  Stearns County      2887      0.4463
# 6   0.470443              41068.936170  Stearns County      1942      0.7166
# 9   0.120052              82502.407069  Stearns County      4702      0.3588
#
#    land_area  per_capita_income  population  population_density state  \
# 1  16.616790            20951.0        8020            482.6443    mn
# 2  37.444820            28021.0        6971            186.1673    mn
# 4  44.001510            32770.0        5264            119.6323    mn
# 6   0.448182            12750.0        3504           7818.2590    mn
# 9   7.873874            31691.0        8504           1080.0270    mn
#
#    total_area  water_area  employ_rate  \
# 1   16.699680    0.082887     0.953660
# 2   39.330500    1.885683     0.959200
# 4   44.600170    0.598656     0.949359
# 6    0.516276    0.068095     0.858153
# 9    8.073771    0.199898     0.981628
#
#    poverty_family_below_poverty_level_rate  heating_fuel_solar_rate  \
# 1                                 0.139073                      0.0
# 2                                 0.068332                      0.0
# 4                                 0.049559                      0.0
# 6                                 0.149254                      0.0
# 9                                 0.006876                      0.0
#
#    median_household_income  household_count  average_household_size  \
# 1                  49778.0             2230                    2.75
# 2                  63355.0             2698                    2.55
# 4                  68401.0             1917                    2.74
# 6                  13333.0              470                    1.78
# 9                  71591.0             3282                    2.59
#
#    housing_unit_count  housing_unit_occupied_count  housing_unit_median_value  \
# 1                2356                         2230                   157000.0
# 2                2909                         2698                   182400.0
# 4                2004                         1917                   208600.0
# 6                 559                          470                   270800.0
# 9                3566                         3282                   173700.0
#
#    housing_unit_median_gross_rent  age_18_24_rate  age_25_34_rate  \
# 1                           733.0        0.377182        0.108603
# 2                           692.0        0.079902        0.093817
# 4                           882.0        0.090616        0.142477
# 6                           512.0        0.804509        0.052226
# 9                          1006.0        0.059384        0.188147
#
#    age_more_than_85_rate  age_75_84_rate  age_35_44_rate  age_45_54_rate  \
# 1               0.009975        0.039526        0.095885        0.091521
# 2               0.032277        0.050782        0.120069        0.151485
# 4               0.005509        0.028875        0.120631        0.149506
# 6               0.004566        0.013984        0.031393        0.032534
# 9               0.007526        0.037747        0.153104        0.106068
#
#    age_65_74_rate  age_55_64_rate  age_10_14_rate  age_15_17_rate  \
# 1        0.034040        0.060973        0.036284        0.024314
# 2        0.079759        0.114474        0.100273        0.057381
# 4        0.060410        0.128609        0.049962        0.039704
# 6        0.010274        0.021689        0.001427        0.017979
# 9        0.063147        0.085254        0.093133        0.031162
#
#    age_5_9_rate  household_type_family_rate  dropout_16_19_inschool_rate  \
# 1      0.061721                    0.609417                     0.966867
# 2      0.065701                    0.726835                     0.989605
# 4      0.103723                    0.768388                     0.946565
# 6      0.008847                    0.142553                     0.995921
# 9      0.085489                    0.709019                     1.000000
#
#    mortgage_with_rate  occupancy_vacant_rate  occupancy_owner_rate  \
# 1            0.644320               0.053480              0.683786
# 2            0.640390               0.072534              0.776212
# 4            0.601471               0.043413              0.678643
# 6            0.741935               0.159213              0.055456
# 9            0.785780               0.079641              0.611329
#
#    age_median  travel_time_average  health_insurance_public_rate  \
# 1        21.9                 22.0                      0.245761
# 2        39.6                 21.0                      0.255264
# 4        34.5                 25.0                      0.272710
# 6        20.0                 15.0                      0.170366
# 9        32.3                 21.0                      0.238342
#
#    health_insurance_none_rate  daily_solar_radiation  net_metering  \
# 1                    0.043890                    NaN            34
# 2                    0.037171                   3.76            34
# 4                    0.023424                   3.76            34
# 6                    0.044091                   3.76            34
# 9                    0.065591                   3.76            34
#
#    feedin_tariff  cooperate_tax  property_tax  sales_tax  rebate  \
# 1              0              0            25         12       0
# 2              0              0            25         12       0
# 4              0              0            25         12       0
# 6              0              0            25         12       0
# 9              0              0            25         12       0
#
#    avg_electricity_retail_rate
# 1                         9.46
# 2                         9.46
# 4                         9.46
# 6                         9.46
# 9                         9.46

# %%
data.describe()
# Out:
#          tile_count  tile_count_residential  total_panel_area_residential  \
# count  53529.000000            53529.000000                  53529.000000
# mean      40.662688               29.076220                    617.478525
# std       98.267574               69.227671                   1504.947253
# min        1.000000                1.000000                      1.813267
# 25%        3.000000                2.000000                     43.002538
# 50%        9.000000                6.000000                    121.744779
# 75%       36.000000               25.000000                    506.153594
# max     4468.000000             1795.000000                  40380.099851
#
#        solar_panel_area_divided_by_area  solar_panel_area_per_capita  \
# count                      53512.000000                 5.352900e+04
# mean                         487.293995                          inf
# std                         1040.157447                          NaN
# min                            0.001006                 3.542230e-04
# 25%                           11.878395                 1.063776e-02
# 50%                           67.366004                 3.006627e-02
# 75%                          428.106535                 1.217762e-01
# max                        16357.357979                          inf
#
#        solar_system_count_residential  solar_system_count_nonresidential  \
# count                    53529.000000                       53529.000000
# mean                        23.871061                           3.438473
# std                         55.681505                           9.284438
# min                          1.000000                           0.000000
# 25%                          2.000000                           0.000000
# 50%                          5.000000                           1.000000
# 75%                         20.000000                           3.000000
# max                       1404.000000                         397.000000
#
#        number_of_solar_system_per_household  number_of_years_of_education  \
# count                          5.352900e+04                  53389.000000
# mean                                    inf                     13.638726
# std                                     NaN                      1.371107
# min                            8.119519e-05                      8.000000
# 25%                            1.282051e-03                     12.723230
# 50%                            3.322259e-03                     13.563940
# 75%                            1.390374e-02                     14.541699
# max                                     inf                     21.000000
#
#           diversity  average_household_income      employed    gini_index  \
# count  53395.000000              53244.000000  53529.000000  53264.000000
# mean       0.323875              77839.266909   2165.073680      0.420269
# std        0.194451              39678.967107   1084.085526      0.062582
# min        0.000000               6910.984848      0.000000      0.006600
# 25%        0.153070              52052.944638   1433.000000      0.377900
# 50%        0.305692              68367.131091   2026.000000      0.414400
# 75%        0.487104              92881.260682   2728.000000      0.455900
# max        0.812441             537130.215827  24075.000000      0.817700
#
#           land_area  per_capita_income    population  population_density  \
# count  53512.000000       53373.000000  53529.000000        53511.000000
# mean      26.551906       30218.332490   4642.219937         4861.421780
# std      180.738029       15532.660586   2162.244018         8827.109784
# min        0.000000         128.000000      0.000000            0.000000
# 25%        0.718702       20182.000000   3213.000000          666.869950
# 50%        1.703273       26944.000000   4371.000000         2530.543000
# 75%        6.834600       36252.000000   5744.000000         5502.668500
# max     9489.732000      213267.000000  53812.000000       223770.200000
#
#          total_area    water_area   employ_rate  \
# count  53512.000000  53512.000000  53343.000000
# mean      27.152256      0.600350      0.914949
# std      182.494694      5.769652      0.052327
# min        0.019939      0.000000      0.000000
# 25%        0.747285      0.000000      0.892086
# 50%        1.798763      0.006876      0.925893
# 75%        7.324130      0.130298      0.950436
# max     9527.715000    883.739400      1.000000
#
#        poverty_family_below_poverty_level_rate  heating_fuel_solar_rate  \
# count                             53270.000000             53304.000000
# mean                                  0.118416                 0.000590
# std                                   0.110305                 0.002788
# min                                   0.000000                 0.000000
# 25%                                   0.038462                 0.000000
# 50%                                   0.084078                 0.000000
# 75%                                   0.165511                 0.000000
# max                                   1.000000                 0.104497
#
#        median_household_income  household_count  average_household_size  \
# count             53201.000000     53529.000000            53280.000000
# mean              61318.351986      1705.242317                2.677241
# std               30159.207767       765.642933                0.524460
# min                3271.000000         0.000000                1.020000
# 25%               40417.000000      1189.000000                2.340000
# 50%               54777.000000      1617.000000                2.610000
# 75%               75431.000000      2125.000000                2.930000
# max              250001.000000     20395.000000                9.750000
#
#        housing_unit_count  housing_unit_occupied_count  \
# count        53529.000000                 53529.000000
# mean          1913.170580                  1705.242317
# std            870.269773                   765.642933
# min              0.000000                     0.000000
# 25%           1335.000000                  1189.000000
# 50%           1802.000000                  1617.000000
# 75%           2368.000000                  2125.000000
# max          25530.000000                 20395.000000
#
#        housing_unit_median_value  housing_unit_median_gross_rent  \
# count               5.265600e+04                    52373.000000
# mean                2.464521e+05                     1066.634926
# std                 2.037697e+05                      445.129738
# min                 9.999000e+03                      164.000000
# 25%                 1.192000e+05                      751.000000
# 50%                 1.837000e+05                      964.000000
# 75%                 3.069000e+05                     1261.000000
# max                 2.000001e+06                     3501.000000
#
#        age_18_24_rate  age_25_34_rate  age_more_than_85_rate  age_75_84_rate  \
# count    53395.000000    53395.000000           53395.000000    53395.000000
# mean         0.099581        0.136919               0.020503        0.044825
# std          0.084907        0.060279               0.021336        0.031623
# min          0.000000        0.000000               0.000000        0.000000
# 25%          0.064501        0.099061               0.007975        0.025197
# 50%          0.084663        0.129057               0.015605        0.039832
# 75%          0.109287        0.164025               0.026892        0.057238
# max          1.000000        1.000000               1.000000        1.000000
#
#        age_35_44_rate  age_45_54_rate  age_65_74_rate  age_55_64_rate  \
# count    53395.000000    53395.000000    53395.000000    53395.000000
# mean         0.126883        0.138360        0.081079        0.125940
# std          0.034784        0.036701        0.041706        0.039561
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.106251        0.116653        0.055402        0.100518
# 50%          0.125874        0.138674        0.076389        0.125761
# 75%          0.147034        0.161219        0.099030        0.150725
# max          0.500000        1.000000        1.000000        1.000000
#
#        age_10_14_rate  age_15_17_rate  age_5_9_rate  \
# count    53395.000000    53395.000000  53395.000000
# mean         0.063186        0.038742      0.062645
# std          0.025452        0.017174      0.025138
# min          0.000000        0.000000      0.000000
# 25%          0.046959        0.027351      0.046662
# 50%          0.063158        0.038375      0.061915
# 75%          0.079309        0.049558      0.077934
# max          0.581818        0.301671      0.246684
#
#        household_type_family_rate  dropout_16_19_inschool_rate  \
# count                53304.000000                 53067.000000
# mean                     0.661756                     0.955893
# std                      0.142675                     0.083560
# min                      0.000000                     0.000000
# 25%                      0.585249                     0.940765
# 50%                      0.679323                     1.000000
# 75%                      0.759691                     1.000000
# max                      1.000000                     1.000000
#
#        mortgage_with_rate  occupancy_vacant_rate  occupancy_owner_rate  \
# count        53107.000000           53315.000000          53315.000000
# mean             0.655466               0.103806              0.569231
# std              0.141457               0.092967              0.216339
# min              0.000000               0.000000              0.000000
# 25%              0.574460               0.046263              0.424373
# 50%              0.671446               0.080920              0.594283
# 75%              0.752838               0.132118              0.735637
# max              1.000000               1.000000              1.000000
#
#          age_median  travel_time_average  health_insurance_public_rate  \
# count  53378.000000         53280.000000                  53344.000000
# mean      38.734271            25.313739                      0.320950
# std        7.685792             6.693020                      0.127795
# min       11.300000             1.000000                      0.000000
# 25%       33.500000            21.000000                      0.229118
# 50%       38.600000            25.000000                      0.309014
# 75%       43.400000            29.000000                      0.397913
# max       83.600000            71.000000                      1.000000
#
#        health_insurance_none_rate  daily_solar_radiation  net_metering  \
# count                53344.000000           49449.000000  53529.000000
# mean                     0.126226               4.322393     14.548955
# std                      0.083939               0.585508      8.569840
# min                      0.000000               3.350000      0.000000
# 25%                      0.062731               3.800000      9.000000
# 50%                      0.109076               4.220000     15.000000
# 75%                      0.171234               4.740000     20.000000
# max                      0.794118               5.650000     35.000000
#
#        feedin_tariff  cooperate_tax  property_tax     sales_tax        rebate  \
# count   53529.000000   53529.000000  53529.000000  53529.000000  53529.000000
# mean        1.577239       0.471670     18.733210      6.379514      2.389303
# std         3.494479       2.459769     16.384267     10.400960      4.216462
# min         0.000000       0.000000      0.000000      0.000000      0.000000
# 25%         0.000000       0.000000      4.000000      0.000000      0.000000
# 50%         0.000000       0.000000     13.000000      0.000000      0.000000
# 75%         0.000000       0.000000     38.000000     11.000000      1.000000
# max        11.000000      16.000000     42.000000     40.000000     14.000000
#
#        avg_electricity_retail_rate
# count                 53529.000000
# mean                     10.987519
# std                       2.653185
# min                       7.250000
# 25%                       8.980000
# 50%                      10.150000
# 75%                      14.720000
# max                      16.650000

# %%
# Ratio of null values in columns
(data.isnull().sum() / data.shape[0]).sort_values(ascending=False)[0:5]
# Out:
# daily_solar_radiation             0.076220
# housing_unit_median_gross_rent    0.021596
# housing_unit_median_value         0.016309
# dropout_16_19_inschool_rate       0.008631
# mortgage_with_rate                0.007884
# dtype: float64

# %%
# Plot histogram of how many null values per row for the "housing_unit_median_gross_rent" feature. 
y = data[data['housing_unit_median_gross_rent'].isnull() == 1].housing_unit_median_gross_rent.index
x = range(1, len(y)+1)
plt.figure(figsize=(8, 5))
a = plt.hist(y, 100)

# %%
# Lets get to work, impute the daily solar radiation according to the mean per county
county_list = data.county.value_counts().index

for county in county_list:
    tmp = data[data['county' ] == county]
    a = tmp['daily_solar_radiation'].fillna( tmp['daily_solar_radiation'].mean())
    data.loc[a.index, 'daily_solar_radiation'] = a.values

# If the mean was also a NaN (Can happen if county has only one entry without solar radiation data)
# We throw away the rows
print('Remaining NaN values is "daily_solar_radiation": %d' % (np.sum(data['daily_solar_radiation'].isnull() == 1)))
# Out:
# Remaining NaN values is "daily_solar_radiation": 16

# %%
orig_num_rows = data.shape[0]
data = data.dropna()
new_num_rows = data.shape[0]
print('%2.2f%% (%d of %d) of rows removed due to NaN values.' % 
      ((orig_num_rows-new_num_rows)*100/orig_num_rows, (orig_num_rows-new_num_rows), orig_num_rows))
# Out:
# 3.76% (2015 of 53529) of rows removed due to NaN values.

# %%
data.max()
# Out:
# tile_count                                          4468
# tile_count_residential                              1795
# total_panel_area_residential                     40380.1
# solar_panel_area_divided_by_area                 15983.3
# solar_panel_area_per_capita                      6.29976
# solar_system_count_residential                      1404
# solar_system_count_nonresidential                    397
# number_of_solar_system_per_household            0.559701
# number_of_years_of_education                      18.615
# diversity                                       0.812441
# average_household_income                          537130
# county                                     Zapata County
# employed                                           24075
# gini_index                                        0.7955
# land_area                                        9489.73
# per_capita_income                                 213267
# population                                         53812
# population_density                                197868
# state                                                 wy
# total_area                                       9527.72
# water_area                                       883.739
# employ_rate                                            1
# poverty_family_below_poverty_level_rate          0.88961
# heating_fuel_solar_rate                         0.104497
# median_household_income                           250001
# household_count                                    20395
# average_household_size                              6.61
# housing_unit_count                                 25530
# housing_unit_occupied_count                        20395
# housing_unit_median_value                          2e+06
# housing_unit_median_gross_rent                      3501
# age_18_24_rate                                   0.97689
# age_25_34_rate                                  0.552669
# age_more_than_85_rate                           0.431992
# age_75_84_rate                                  0.462324
# age_35_44_rate                                      0.35
# age_45_54_rate                                  0.287037
# age_65_74_rate                                  0.493286
# age_55_64_rate                                   0.35736
# age_10_14_rate                                  0.234295
# age_15_17_rate                                  0.301671
# age_5_9_rate                                    0.219082
# household_type_family_rate                      0.992629
# dropout_16_19_inschool_rate                            1
# mortgage_with_rate                                     1
# occupancy_vacant_rate                           0.925961
# occupancy_owner_rate                            0.981339
# age_median                                          83.6
# travel_time_average                                   64
# health_insurance_public_rate                    0.920179
# health_insurance_none_rate                      0.788968
# daily_solar_radiation                               5.65
# net_metering                                          35
# feedin_tariff                                         11
# cooperate_tax                                         16
# property_tax                                          42
# sales_tax                                             40
# rebate                                                14
# avg_electricity_retail_rate                        16.65
# dtype: object

# %%
# create a new column for solar density, deployed solar systems (residential) per Thousands households.
data['sol_density'] = (data['solar_system_count_residential'] / data['household_count']) * 1000

# %%
# scatter of density vs. radiation
data.plot.scatter( x = 'daily_solar_radiation', y = 'sol_density')

# %%
def CalcSolarDensityVsMeanOfColumn( df, col_name, col_grid ):
    '''
    INPUT:
    df - A pandas dataframe from the DeepSolar dataframe
    col_name - some numerical column in the dataframe other than 'sol_density'
    col_grid - A grid of values that the column will be quantized into. e.g. the grid can be:
               [0,1,2,3,...,100] and all values of the column will be rounded to the nearest grid point.
    OUTPUT:
    An array of the AVERAGED solar systems installations per thousand households across the grid point. 
    The function help plotting the 'sol_density' column vs. Other columns. How? Since we have a lot of data, a straight
    forward scatter plot looks bad. Instead, we take any data column and reduce the number of points within it by "binning" of it's values
    to a smaller grid. (Just like in a histogram). Then, per each bin, we calculate an average of all 'sol_density' values we have.
    '''
    
    # Init empty result list
    solar_systems_per_thousand_households = []
    
    # Quantize the column value according to the supplied grid, get back the indices
    indices = np.digitize( df[col_name], np.sort(col_grid) )
    
    # Go over grid values
    for val in range(1,len(col_grid)+1):
        
        # Get susbset of table 
        tmp = df.loc[ indices == val]
        
        # Append the mean of solar systems density
        solar_systems_per_thousand_households.append(np.mean(tmp['sol_density']))    

    return solar_systems_per_thousand_households

# %%
# calc the average density per each level of daily solar radiation
n_grid_points = 100
x = np.linspace(data['daily_solar_radiation'].min(), data['daily_solar_radiation'].max(), n_grid_points)
y = CalcSolarDensityVsMeanOfColumn(data, 'daily_solar_radiation', x)

# Plot
d = {"Ave. daily solar radiation [kWh/$m^2$/d]": x, "#Solar systems per thousand households": y}
sns.set(font_scale = 1)
sns.lmplot(x = "Ave. daily solar radiation [kWh/$m^2$/d]", y = "#Solar systems per thousand households",
           data = pd.DataFrame(d), ci = 95, order = 4, aspect = 1.5)

# %%
# Average income
# calc the average density per each level of daily solar radiation
n_grid_points = 50
col_name = 'average_household_income'

x = np.linspace(data[col_name].min(), 200e3 ,n_grid_points)
y = CalcSolarDensityVsMeanOfColumn(data, col_name, x)

# Plot
d = {col_name: x, "#Solar systems per thousand households": y}
sns.set(font_scale = 1)
sns.lmplot(x = col_name, y = "#Solar systems per thousand households",
           data = pd.DataFrame(d), ci = 95, order = 4, aspect = 1.5)

# %%
# Education years
n_grid_points = 100
col_name = 'number_of_years_of_education'

x = np.linspace(data[col_name].min(), data[col_name].max() ,n_grid_points)
y = CalcSolarDensityVsMeanOfColumn(data, col_name, x)

# Plot
d = {col_name: x, "#Solar systems per thousand households": y}
sns.set(font_scale = 1)
fgrid = sns.lmplot(x = col_name, y = "#Solar systems per thousand households",
                   data = pd.DataFrame(d), ci = 95, order = 3, aspect = 1.5)
ax = fgrid.axes[0][0]
ax.axis([10, 18, 0, 30])
# Out:
# [10, 18, 0, 30]

# %%
# Diversity index
n_grid_points = 100
col_name = 'diversity'

x = np.linspace(data[col_name].min(), data[col_name].max() ,n_grid_points)
y = CalcSolarDensityVsMeanOfColumn(data, col_name, x)

# Plot
d = {col_name: x, "#Solar systems per thousand households": y}
sns.set(font_scale = 1)
sns.lmplot(x = col_name, y = "#Solar systems per thousand households",
           data = pd.DataFrame(d), ci = 95, order = 3, aspect = 1.5)

# The more diverse the area the less solar installations. Index is probability that sampling of 2 people will have the same race. If low, means high diversity. If high, means low diversity. 
# This means that we need to further segment according to race to check who are installing the most.

# %%
# Diversity index
n_grid_points = 50
col_name = 'population_density'

x = np.logspace(1,5 ,n_grid_points)
y = CalcSolarDensityVsMeanOfColumn(data, col_name, x)

# Plot
d = {col_name: x, "#Solar systems per thousand households": y}
fgrid = sns.lmplot(x = col_name, y = "#Solar systems per thousand households",
           data = pd.DataFrame(d), lowess = True, aspect = 1.5)
ax = fgrid.axes[0][0]
ax.set_xscale('log')
ax.axis([10, 1e5, 0, 25])
# Out:
# [10, 100000.0, 0, 25]

# %%
# Diversity index
n_grid_points = 100
col_name = 'gini_index'

x = np.linspace(data[col_name].min(), data[col_name].max(), n_grid_points)
y = CalcSolarDensityVsMeanOfColumn(data, col_name, x)

# Plot
d = {col_name: x, "#Solar systems per thousand households": y}
sns.set(font_scale = 1)
sns.lmplot(x = col_name, y = "#Solar systems per thousand households",
           data = pd.DataFrame(d), ci = 95, order = 3, aspect = 1.5)
